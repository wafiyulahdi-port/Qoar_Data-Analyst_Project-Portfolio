# %%
# !curl -sL https://deb.nodesource.com/setup_18.x | sudo -E bash -
# !sudo apt-get install -y nodejs

# %%
data = 'tweet_data_2024.csv'
search_keyword = '#tagar'
limit = 1000000000 #optional

# !npx --yes tweet-harvest@latest -o "{data}" -s "{search_keyword}"  -l {limit} --token ""

# %%
import pandas as pd

data = pd.read_csv("dir/file.csv")
data

# %% [markdown]
# The results of the scrape on this file are then processed in the sentiment_shopee file because the file structure is similar.
